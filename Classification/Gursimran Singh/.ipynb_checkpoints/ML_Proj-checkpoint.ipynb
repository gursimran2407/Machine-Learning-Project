# %%
import scipy.io
from scipy.io import arff
from io import StringIO
import pandas as pd
import numpy as np

# %%
data = arff.loadarff("../Datasets/9.ThoraticSurgeryData/ThoraricSurgery.arff")
df = pd.DataFrame(data[0])

df.head()
# Out:
#        DGN  PRE4  PRE5     PRE6  PRE7  PRE8  PRE9 PRE10 PRE11    PRE14 PRE17  \
# 0  b'DGN2'  2.88  2.16  b'PRZ1'  b'F'  b'F'  b'F'  b'T'  b'T'  b'OC14'  b'F'
# 1  b'DGN3'  3.40  1.88  b'PRZ0'  b'F'  b'F'  b'F'  b'F'  b'F'  b'OC12'  b'F'
# 2  b'DGN3'  2.76  2.08  b'PRZ1'  b'F'  b'F'  b'F'  b'T'  b'F'  b'OC11'  b'F'
# 3  b'DGN3'  3.68  3.04  b'PRZ0'  b'F'  b'F'  b'F'  b'F'  b'F'  b'OC11'  b'F'
# 4  b'DGN3'  2.44  0.96  b'PRZ2'  b'F'  b'T'  b'F'  b'T'  b'T'  b'OC11'  b'F'
#
#   PRE19 PRE25 PRE30 PRE32   AGE Risk1Yr
# 0  b'F'  b'F'  b'T'  b'F'  60.0    b'F'
# 1  b'F'  b'F'  b'T'  b'F'  51.0    b'F'
# 2  b'F'  b'F'  b'T'  b'F'  59.0    b'F'
# 3  b'F'  b'F'  b'F'  b'F'  54.0    b'F'
# 4  b'F'  b'F'  b'T'  b'F'  73.0    b'T'

# %% [markdown]
# Preprocessing

# %%
str_df = df.select_dtypes([np.object]) 
str_df = str_df.stack().str.decode('utf-8').unstack()
str_df
# Out:
#       DGN  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19 PRE25 PRE30  \
# 0    DGN2  PRZ1    F    F    F     T     T  OC14     F     F     F     T
# 1    DGN3  PRZ0    F    F    F     F     F  OC12     F     F     F     T
# 2    DGN3  PRZ1    F    F    F     T     F  OC11     F     F     F     T
# 3    DGN3  PRZ0    F    F    F     F     F  OC11     F     F     F     F
# 4    DGN3  PRZ2    F    T    F     T     T  OC11     F     F     F     T
# 5    DGN3  PRZ1    F    F    F     T     F  OC11     F     F     F     F
# 6    DGN3  PRZ1    F    F    F     T     F  OC12     T     F     F     T
# 7    DGN2  PRZ1    F    F    F     T     F  OC11     F     F     T     T
# 8    DGN3  PRZ2    F    F    F     T     T  OC11     F     F     F     T
# 9    DGN3  PRZ1    F    F    F     T     F  OC11     F     F     F     T
# 10   DGN3  PRZ0    F    T    F     T     F  OC12     F     F     F     F
# 11   DGN3  PRZ1    F    F    F     F     F  OC12     F     F     F     T
# ...

# %%
#Converting T F values to 0 1 respectivly:
df[['PE', 'COL4']] = (df[['COL2', 'COL4']] == 'TRUE').astype(int)
